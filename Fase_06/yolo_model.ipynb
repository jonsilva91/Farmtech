# %% [markdown]
# # FarmeTech - Visão computacional
#
# Projeto tem como objetivo mostra a eficiência da arquitetura YOLO, uma arquitetura de visão computacional. Vamos abordar somente a detecção de objetos.
#
# Para fins demostrativos vamos utilizar um dataset de gatos e cachorros, **mas, é bom lembrar que o mesmo modelo treinado com o devido dataset pode ser aplicado para outra classes de objetos.**

# %%
# Clonando o repositório do YOLO v5

# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17608, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 17608 (delta 7), reused 2 (delta 2), pack-reused 17593 (from 2)
# Receiving objects: 100% (17608/17608), 16.87 MiB | 27.33 MiB/s, done.
# Resolving deltas: 100% (11986/11986), done.

# %% [markdown]
# IMPORTANTE: É importante garantir que você está na pasta correta.

# %%
# Garantindo que estamos no diretório correto que foi clonado no comando anterior

# %cd yolov5
# Out:
# /home/henrique/fiap/fase-06/yolov5

# %%
# Instalando depedências do repositório YOLO v5

# %pip install -r requirements.txt -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Carregando libs e inicialização de variáveis
#
# Vamos carregar as libs necessárias para manipulação dos dados e visualizações tanto de imagens quando de gráficos utilizados no comparativo.

# %%
# Bibliotecas padrão
import os
from pathlib import Path
import yaml

# Bibliotecas para manipulação de dados
import numpy as np
import pandas as pd

# Bibliotecas para visualização
import matplotlib.pyplot as plt
import seaborn as sns

# Bibliotecas dde manipulação de imagens
import cv2

# Configurações de visualização
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

# %%
# define caminho da pasta do meu projeto no google drive

DRIVE_PATH = '../farmtech_yolo_project'

# Caminho para o dataset principal
dataset_path = os.path.join(DRIVE_PATH, 'dataset')

# Caminho para as imagens de teste
test_images_path = os.path.join(DRIVE_PATH, 'dataset', 'test', 'images')

# %% [markdown]
# ## Visualizando as imagens do dataset
#
# Para entender se o nosso dataset está sendo carregado corretamente, vamos imprimir amostra aleatórias das imagens contidas no dataset

# %%
# visualizar amostra aleatória das imagens do dataset

import random

def visualize_samples(dataset_path, split='train', num_samples=6):
    """Visualiza amostras aleatórias do dataset"""
    img_dir = os.path.join(dataset_path, split, 'images')
    images = [f for f in os.listdir(img_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]

    # Selecionar amostras aleatórias
    samples = random.sample(images, min(num_samples, len(images)))

    # Criar grid de visualização
    cols = 3
    rows = (len(samples) + cols - 1) // cols
    fig, axes = plt.subplots(rows, cols, figsize=(15, 5*rows))
    axes = axes.flatten() if isinstance(axes, np.ndarray) else [axes]

    for idx, img_name in enumerate(samples):
        img_path = os.path.join(img_dir, img_name)
        # Ler imagem com OpenCV e converter de BGR para RGB
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        # Obter dimensões da imagem
        height, width = img.shape[:2]

        axes[idx].imshow(img)
        axes[idx].set_title(f'{img_name}\nTamanho: {width}x{height}', fontsize=10)
        axes[idx].axis('off')

    # Ocultar eixos não utilizados
    for idx in range(len(samples), len(axes)):
        axes[idx].axis('off')

    plt.suptitle(f'Amostras do Conjunto de {split.upper()}', fontsize=16, fontweight='bold', y=1.00)
    plt.tight_layout()
    plt.show()

# Visualizar amostras de treinamento
visualize_samples(dataset_path, 'train', num_samples=6)

# %% [markdown]
# ## Configuração base do modelo
#
# Vamos criar um arquivo dataset.yml na raiz do diretório do yaml.
#
# Esse arquivos contém configurações base que o modelo utilizará no treinamento. Por exemplo: o caminho de saída dos dataset de cada etapa, o nomes e quantidade de classes.

# %%
# Definir as classes
CLASS_NAMES = ['cachorro', 'gato']

# Criar arquivo YAML de configuração
yaml_content = {
    'path': dataset_path,
    'train': 'train/images',
    'val': 'valid/images',
    'test': 'test/images',
    'nc': len(CLASS_NAMES),  # número de classes
    'names': CLASS_NAMES
}

# Salvar arquivo YAML
yaml_path = 'dataset.yaml'
with open(yaml_path, 'w') as f:
    yaml.dump(yaml_content, f, default_flow_style=False)

print("✅ Arquivo de configuração criado: dataset.yaml\n")
print("📋 Conteúdo do arquivo:\n")
with open(yaml_path, 'r') as f:
    print(f.read())
# Out:
# ✅ Arquivo de configuração criado: dataset.yaml
#
# 📋 Conteúdo do arquivo:
#
# names:
# - cachorro
# - gato
# nc: 2
# path: ../farmtech_yolo_project/dataset
# test: test/images
# train: train/images
# val: valid/images

# %% [markdown]
# ## Treinando o Modelo
#
# Vamos treinar 2 modelos, um com 30 épocas e outro com 60 épocas.
#
# Épocas são a quantidade de vezes que o dataset completo passa pelo algoritmo.
#
# **Vamos resaltar alguns parametro do comando de treinamento**:
# --img 640: As imagens serão redimencionadas onde o lado maior da imagem será igual a 640, assim mantendo a proporção.
# --epochs 30: Quantidade de épocas
# --data dataset.yml: Nosso arquivo de configuração base que criamos acima.
# --name: nome do treinamento (os arquivos de output e métricas do modelo terão esse nome)

# %% [markdown]
# ### Treinar o modelo de 30 épocas.

# %%
# !python train.py --img 640 --batch 16 --epochs 30 --data dataset.yaml --weights yolov5s.pt --name farmtech_30epochs --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=farmtech_30epochs, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-440-gf5ebc52c Python-3.12.3 torch-2.8.0+cu128 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7025023 parameters, 7025023 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/train/
# train: Caching images (0.1GB ram): 100%|██████████| 64/64 [00:00<00:00, 2430.58i
# val: Scanning /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/valid/la
# val: Caching images (0.0GB ram): 100%|██████████| 8/8 [00:00<00:00, 691.15it/s]
#
# AutoAnchor: 2.55 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/farmtech_30epochs/labels.jpg...
# /home/henrique/fiap/fase-06/yolov5/train.py:357: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/farmtech_30epochs
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1272    0.03118    0.03302         47        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1257     0.0309    0.03466         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1112    0.03016    0.02973         39        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/29         0G     0.1043    0.02992    0.02714         43        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9    0.00217      0.125    0.00491    0.00176
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G     0.1271    0.03091    0.03005         48        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G     0.1245     0.0307    0.02882         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G     0.1226    0.03121    0.03105         56        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/29         0G     0.1228    0.03137     0.0319         56        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9     0.0027       0.25     0.0167    0.00468
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G     0.1154    0.02858    0.03437         39        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G     0.1163    0.03074    0.03304         55        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G      0.117    0.02968    0.03144         40        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/29         0G     0.1148     0.0299    0.03218         46        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9    0.00239       0.25    0.00978    0.00209
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/29         0G     0.1178    0.02847    0.02641         43        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/29         0G    0.09236    0.02842    0.02282         42        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/29         0G    0.08339    0.03036    0.02183         55        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/29         0G    0.08437    0.03091    0.02307         48        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9    0.00334       0.45     0.0194    0.00451
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/29         0G     0.1054    0.02685    0.03351         35        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/29         0G    0.08284    0.02783    0.02707         38        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/29         0G    0.09096    0.02765    0.03133         39        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/29         0G     0.0906    0.02885    0.03059         50        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9    0.00372       0.45       0.07     0.0399
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/29         0G    0.09183     0.0325    0.02804         53        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/29         0G    0.08636    0.03418    0.02734         52        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/29         0G    0.07727    0.03389     0.0246         55        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/29         0G    0.07833    0.03442    0.02488         58        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9    0.00334       0.45     0.0735     0.0285
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/29         0G    0.05507    0.02852    0.01787         41        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/29         0G    0.06781     0.0301    0.02169         48        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/29         0G    0.07159    0.03035    0.02302         48        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/29         0G     0.0711    0.02975    0.02587         42        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9    0.00986      0.575      0.137      0.104
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/29         0G    0.07917    0.03578    0.02523         57        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/29         0G    0.07541    0.03266    0.02457         42        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/29         0G    0.06744    0.03169    0.02224         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/29         0G    0.07592    0.03239    0.02193         54        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9     0.0259      0.775      0.182      0.149
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/29         0G    0.06598    0.03037    0.02145         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/29         0G    0.06554    0.03004    0.01981         47        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/29         0G    0.05846    0.02939    0.01916         41        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/29         0G    0.05506    0.02888    0.01884         41        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9     0.0942       0.35      0.215      0.162
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/29         0G    0.04401    0.02509    0.01664         35        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/29         0G    0.04665    0.02689    0.01707         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/29         0G    0.05678    0.02992    0.01832         58        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/29         0G    0.06044    0.03103    0.01881         53        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9       0.29      0.225      0.314      0.211
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       10/29         0G    0.04144    0.03082    0.01781         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       10/29         0G    0.05131    0.03069    0.01969         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       10/29         0G    0.05966    0.03049    0.02116         51        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       10/29         0G    0.06256    0.03339    0.02059         69        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.283      0.775      0.428      0.236
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       11/29         0G    0.04449    0.02689    0.01771         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       11/29         0G    0.04267    0.02488    0.01752         36        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       11/29         0G    0.04305    0.02564    0.01728         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       11/29         0G    0.04313    0.02525    0.01735         37        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.398        0.7      0.463       0.23
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       12/29         0G    0.06503    0.03362    0.01811         55        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       12/29         0G    0.05458    0.02932    0.01772         41        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       12/29         0G    0.04858     0.0267    0.01756         35        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       12/29         0G    0.04594    0.02623    0.01733         41        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.267      0.425      0.341      0.151
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       13/29         0G    0.02992    0.01928    0.01645         32        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       13/29         0G    0.03958    0.02337    0.02647         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       13/29         0G    0.03865    0.02564    0.02246         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       13/29         0G    0.04388    0.02782    0.02088         56        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.368      0.425      0.413      0.185
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       14/29         0G    0.04317    0.02091    0.01582         37        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       14/29         0G    0.04031    0.02403    0.01582         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       14/29         0G    0.05206    0.02678    0.01643         53        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       14/29         0G    0.05788    0.02757    0.01597         50        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.496      0.441      0.485      0.247
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       15/29         0G    0.04035    0.02112    0.01646         39        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       15/29         0G    0.05234    0.02507    0.01651         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       15/29         0G     0.0607    0.02666    0.01745         54        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       15/29         0G    0.05754     0.0271    0.02067         54        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.397      0.686      0.502      0.273
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       16/29         0G    0.03556    0.02612    0.01465         47        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       16/29         0G    0.03732    0.02651    0.01465         48        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       16/29         0G    0.03695    0.02503    0.01509         39        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       16/29         0G    0.04315    0.02574    0.01766         49        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.385        0.9      0.524      0.293
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       17/29         0G    0.07005    0.02843    0.02237         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       17/29         0G    0.06446    0.02845    0.01978         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       17/29         0G    0.05462    0.02596    0.01766         37        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       17/29         0G    0.05616     0.0273    0.01695         52        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.498      0.493      0.501      0.333
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       18/29         0G    0.03514    0.02109    0.01393         42        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       18/29         0G    0.03424    0.02196    0.01438         43        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       18/29         0G    0.04252    0.02213    0.02273         43        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       18/29         0G      0.048    0.02212    0.02202         46        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.372      0.834      0.495      0.323
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/29         0G    0.03674    0.02143    0.01667         44        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/29         0G    0.03406    0.02187    0.01603         42        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/29         0G    0.03399     0.0224    0.01528         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/29         0G    0.03326    0.02192    0.01516         41        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.449      0.675      0.502      0.305
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       20/29         0G    0.05781    0.04201    0.01477         73        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       20/29         0G     0.0554    0.03485    0.01489         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       20/29         0G    0.05589    0.03463    0.01445         59        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       20/29         0G    0.04996    0.03167     0.0142         45        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.603       0.67      0.601      0.349
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       21/29         0G    0.03361     0.0235    0.01408         48        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       21/29         0G    0.04748    0.02653    0.01395         51        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       21/29         0G    0.04263    0.02478     0.0137         41        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       21/29         0G    0.04068    0.02468    0.01353         46        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.351      0.678      0.467      0.244
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.03391    0.01963    0.01301         43        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.04703    0.02523    0.01359         56        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.05238     0.0243    0.01345         43        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/29         0G    0.05432    0.02476    0.01378         52        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.548      0.675      0.557      0.311
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.04942    0.02309    0.01412         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.05175    0.02503    0.01433         57        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.04453    0.02368    0.01371         47        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/29         0G    0.04947    0.02348    0.01443         41        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.632      0.565      0.631       0.34
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/29         0G    0.04764    0.03024     0.0125         57        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/29         0G    0.04957    0.02575    0.01448         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/29         0G    0.04571    0.02398    0.01356         40        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/29         0G    0.04927    0.02313     0.0147         41        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.473      0.675       0.58      0.297
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       25/29         0G    0.02783    0.01734    0.01163         35        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       25/29         0G    0.02915    0.01899    0.01358         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       25/29         0G    0.03713    0.02319    0.01335         62        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       25/29         0G    0.03673    0.02363     0.0132         47        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.493      0.675      0.592      0.293
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       26/29         0G    0.03228    0.02396    0.01125         48        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       26/29         0G    0.04464     0.0243    0.01181         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       26/29         0G    0.04518    0.02337    0.01265         44        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       26/29         0G    0.04498    0.02344    0.01233         47        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.699      0.668      0.676      0.349
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       27/29         0G    0.04566    0.02167    0.01685         50        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       27/29         0G    0.05179    0.02643    0.01479         61        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       27/29         0G    0.05253    0.02506    0.01478         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       27/29         0G    0.05079     0.0243    0.01619         45        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.556      0.665      0.662      0.329
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       28/29         0G    0.02862    0.01764    0.01626         42        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       28/29         0G    0.04196    0.02182    0.01388         51        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       28/29         0G    0.04405    0.02284    0.01317         52        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       28/29         0G      0.049    0.02448    0.01304         61        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.723       0.55      0.663      0.325
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29         0G     0.0607    0.02323     0.0158         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29         0G    0.04477    0.02213    0.01343         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29         0G    0.03983    0.02197    0.01274         47        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       29/29         0G    0.04291    0.02209     0.0137         47        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9       0.66      0.552      0.657      0.346
#
# 30 epochs completed in 0.152 hours.
# Optimizer stripped from runs/train/farmtech_30epochs/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/farmtech_30epochs/weights/best.pt, 14.4MB
#
# Validating runs/train/farmtech_30epochs/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.701       0.67      0.677      0.347
#               cachorro          8          5      0.746       0.59      0.653      0.274
#                   gato          8          4      0.657       0.75      0.702      0.419
# Results saved to runs/train/farmtech_30epochs

# %% [markdown]
# ### Treinar o modelo de 60 épocas.

# %%
# !python train.py --img 640 --batch 16 --epochs 60 --data dataset.yaml --weights yolov5s.pt --name farmtech_60epochs --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=farmtech_60epochs, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-440-gf5ebc52c Python-3.12.3 torch-2.8.0+cu128 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████████████████████████████████| 14.1M/14.1M [00:00<00:00, 46.7MB/s]
#
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7025023 parameters, 7025023 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/train/
# train: Caching images (0.1GB ram): 100%|██████████| 64/64 [00:00<00:00, 3699.50i
# val: Scanning /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/valid/la
# val: Caching images (0.0GB ram): 100%|██████████| 8/8 [00:00<00:00, 1188.15it/s]
#
# AutoAnchor: 2.55 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/farmtech_60epochs/labels.jpg...
# /home/henrique/fiap/fase-06/yolov5/train.py:357: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/farmtech_60epochs
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/59         0G     0.1272    0.03118    0.03302         47        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/59         0G     0.1257     0.0309    0.03466         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/59         0G     0.1112    0.03016    0.02973         39        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/59         0G     0.1043    0.02992    0.02714         43        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9    0.00217      0.125    0.00491    0.00176
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/59         0G     0.1271    0.03091    0.03005         48        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/59         0G     0.1245     0.0307    0.02882         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/59         0G     0.1226    0.03121    0.03104         56        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        1/59         0G     0.1228    0.03137    0.03189         56        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9     0.0027       0.25     0.0167    0.00468
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/59         0G     0.1152    0.02858    0.03437         39        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/59         0G     0.1162    0.03075    0.03303         55        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/59         0G     0.1169    0.02969    0.03144         40        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        2/59         0G     0.1147    0.02991    0.03217         46        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9     0.0024       0.25    0.00961    0.00204
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/59         0G     0.1174    0.02849    0.02639         43        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/59         0G    0.09206    0.02844     0.0228         42        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/59         0G    0.08308    0.03039    0.02183         55        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/59         0G    0.08416    0.03094    0.02308         48        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9    0.00334       0.45     0.0186    0.00512
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/59         0G     0.1047    0.02684    0.03368         35        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/59         0G    0.08254    0.02777    0.02713         38        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/59         0G    0.09038    0.02758    0.03074         39        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        4/59         0G    0.09027    0.02881    0.02996         50        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9    0.00334       0.45     0.0247     0.0132
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/59         0G    0.09181    0.03261    0.02782         53        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/59         0G    0.08589    0.03427    0.02712         52        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/59         0G    0.07685    0.03394    0.02445         55        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        5/59         0G    0.07768    0.03445    0.02465         58        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9    0.00391      0.575      0.137      0.043
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/59         0G    0.05561    0.02829    0.01774         41        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/59         0G    0.06732    0.03015     0.0214         48        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/59         0G    0.07168    0.03034    0.02304         48        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        6/59         0G    0.07083    0.02969    0.02582         42        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9    0.00571      0.575      0.137     0.0461
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/59         0G    0.07785    0.03564    0.02415         57        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/59         0G    0.07579    0.03246    0.02341         42        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/59         0G    0.06751    0.03155    0.02144         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        7/59         0G    0.07615    0.03231    0.02141         54        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9    0.00333      0.575      0.206      0.109
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/59         0G    0.07887    0.03017     0.0223         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/59         0G    0.07415    0.02962     0.0206         47        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/59         0G    0.06431    0.02898    0.01957         41        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/59         0G    0.05922    0.02856    0.01909         41        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9     0.0298      0.675       0.34      0.172
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/59         0G    0.04355    0.02473    0.01623         35        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/59         0G    0.04531    0.02682    0.01677         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/59         0G    0.05558    0.02971    0.01769         58        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        9/59         0G    0.05893    0.03089    0.01784         53        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 0.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.343       0.55      0.354       0.18
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       10/59         0G    0.04171       0.03    0.01764         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       10/59         0G    0.05054    0.02978    0.01956         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       10/59         0G    0.05953    0.02976    0.01966         51        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       10/59         0G    0.06296    0.03284    0.01939         69        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9       0.44      0.325       0.41      0.193
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       11/59         0G    0.04318    0.02678    0.01697         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       11/59         0G    0.04013    0.02457     0.0166         36        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       11/59         0G    0.04098    0.02519    0.01665         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       11/59         0G    0.04168    0.02465     0.0169         37        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9       0.37      0.434      0.475      0.212
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       12/59         0G    0.06219    0.03356    0.01635         55        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       12/59         0G     0.0518    0.02921    0.01665         41        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       12/59         0G    0.04616    0.02631    0.01642         35        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       12/59         0G      0.044    0.02572    0.01643         41        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.345       0.65       0.54      0.355
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       13/59         0G    0.03462    0.01908    0.01607         32        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       13/59         0G    0.04355    0.02267    0.02731         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       13/59         0G    0.04159     0.0248    0.02332         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       13/59         0G    0.04593    0.02687    0.02157         56        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.331       0.69      0.594      0.466
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       14/59         0G    0.04038    0.02045     0.0148         37        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       14/59         0G    0.03878    0.02282    0.01515         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       14/59         0G    0.05048     0.0256    0.01534         53        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       14/59         0G    0.05657    0.02633    0.01509         50        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.337       0.65      0.369      0.212
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       15/59         0G    0.04439    0.01904    0.01503         39        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       15/59         0G     0.0533    0.02255     0.0158         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       15/59         0G    0.06027    0.02471    0.01695         54        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       15/59         0G    0.05669    0.02524    0.02014         54        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.402      0.775      0.474      0.288
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       16/59         0G    0.03431    0.02477    0.01382         47        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       16/59         0G    0.03641    0.02516    0.01384         48        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       16/59         0G     0.0371    0.02329      0.014         39        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       16/59         0G    0.04286    0.02381    0.01714         49        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.304      0.732      0.379      0.187
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       17/59         0G    0.06906     0.0258    0.02003         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       17/59         0G    0.06619    0.02635    0.01864         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       17/59         0G    0.05775    0.02373    0.01654         37        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       17/59         0G     0.0599    0.02496    0.01611         52        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.439      0.775      0.488      0.266
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       18/59         0G    0.03338     0.0197     0.0124         42        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       18/59         0G    0.03263    0.02102    0.01243         43        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       18/59         0G    0.04023    0.02123    0.02198         43        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       18/59         0G    0.04176    0.02099    0.02223         46        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.502      0.778      0.618      0.314
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/59         0G    0.03915    0.02063    0.01653         44        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/59         0G     0.0371    0.02071    0.01565         42        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/59         0G     0.0371    0.02095    0.01527         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       19/59         0G    0.03702    0.02034    0.01519         41        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.386      0.775      0.476      0.276
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       20/59         0G    0.06141    0.03999    0.01422         73        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       20/59         0G    0.05867    0.03237     0.0163         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       20/59         0G    0.05948    0.03195    0.01458         59        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       20/59         0G    0.05336    0.02906    0.01383         45        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9       0.59      0.759      0.582      0.331
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       21/59         0G    0.03653    0.02195    0.01315         48        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       21/59         0G    0.05046    0.02487     0.0127         51        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       21/59         0G    0.04604    0.02311    0.01267         41        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       21/59         0G    0.04383    0.02321     0.0124         46        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.308      0.775      0.355      0.189
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/59         0G    0.03664    0.01731    0.01217         43        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/59         0G    0.04721    0.02317     0.0122         56        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/59         0G    0.05395    0.02208    0.01157         43        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       22/59         0G    0.05705    0.02235    0.01171         52        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.668      0.775      0.635      0.435
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/59         0G    0.05028    0.02192    0.01196         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/59         0G    0.05331     0.0234    0.01278         57        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/59         0G    0.04606    0.02203    0.01159         47        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/59         0G    0.04681    0.02205    0.01212         41        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9       0.38      0.895       0.54      0.353
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/59         0G    0.05725    0.02759    0.01096         57        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/59         0G    0.05876    0.02302    0.01427         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/59         0G    0.05252    0.02146    0.01255         40        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       24/59         0G    0.05325    0.02052    0.01304         41        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.406      0.675      0.592      0.393
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       25/59         0G    0.03312    0.01457    0.01088         35        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       25/59         0G    0.03385    0.01659    0.01246         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       25/59         0G    0.04052    0.02064    0.01194         62        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       25/59         0G    0.04027    0.02111    0.01137         47        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.727      0.503      0.636      0.446
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       26/59         0G    0.03386    0.02211   0.009752         48        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       26/59         0G    0.04729     0.0224     0.0095         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       26/59         0G    0.05236     0.0217     0.0111         44        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       26/59         0G    0.05572    0.02165    0.01054         47        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9       0.71      0.425      0.626      0.404
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       27/59         0G    0.04973    0.02136    0.01324         50        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       27/59         0G    0.05407    0.02625    0.01219         61        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       27/59         0G    0.05419    0.02455    0.01206         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       27/59         0G    0.05393     0.0237    0.01538         45        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.469      0.707      0.652      0.443
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       28/59         0G    0.02956    0.01666    0.01055         42        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
#       49/59         0G    0.02071    0.01721   0.004102         48        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/59         0G     0.0266    0.01846   0.004565         51        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/59         0G    0.02522    0.01781   0.004205         40        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.566       0.73      0.703      0.467
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       50/59         0G    0.03785    0.02042   0.006666         51        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       50/59         0G    0.03984    0.01821   0.007439         42        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       50/59         0G    0.04226    0.01984   0.007378         51        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       50/59         0G      0.041    0.01885   0.009842         40        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.714      0.736      0.745      0.487
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       51/59         0G    0.04521    0.02049     0.0091         43        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       51/59         0G    0.03274    0.01636   0.008478         37        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       51/59         0G    0.03658    0.01597   0.009126         38        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       51/59         0G     0.0346    0.01629    0.01043         46        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.497        0.8      0.778      0.559
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       52/59         0G    0.01793    0.01849   0.003539         53        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       52/59         0G     0.0185    0.01799   0.004092         47        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       52/59         0G    0.01986    0.01796   0.004588         44        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       52/59         0G    0.02259    0.01927   0.004546         57        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.764      0.575      0.735      0.505
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       53/59         0G    0.02407    0.01469   0.005123         35        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       53/59         0G    0.03296    0.01891   0.004768         56        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       53/59         0G    0.02872    0.01801   0.005457         49        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       53/59         0G    0.03068    0.01894   0.005268         52        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.825      0.656      0.764      0.565
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       54/59         0G    0.01774    0.01539   0.006596         47        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       54/59         0G    0.01788    0.01423   0.005945         37        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       54/59         0G    0.02293    0.01524   0.005979         45        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       54/59         0G    0.02863    0.01497   0.007569         45        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.856      0.683      0.724      0.538
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       55/59         0G    0.02229    0.01768   0.004922         42        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       55/59         0G    0.02015     0.0162   0.006732         41        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       55/59         0G     0.0263    0.01814   0.005851         51        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       55/59         0G    0.02886    0.01783   0.005467         45        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.818        0.7      0.741      0.539
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       56/59         0G    0.01546    0.01365   0.004044         41        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       56/59         0G    0.01811    0.01643   0.004107         52        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       56/59         0G    0.02453     0.0178   0.006289         52        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       56/59         0G    0.02786    0.01972   0.006019         59        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9       0.83        0.7      0.743      0.562
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       57/59         0G    0.01853    0.01615   0.004582         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       57/59         0G    0.01906    0.01497   0.004077         36        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       57/59         0G    0.02148     0.0173   0.003675         57        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       57/59         0G    0.02037    0.01637   0.003732         43        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.769      0.674      0.691      0.522
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       58/59         0G    0.01896    0.01484    0.00393         43        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       58/59         0G    0.02006    0.01647   0.003714         46        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       58/59         0G    0.02359     0.0165   0.004064         44        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       58/59         0G    0.02685    0.01674   0.003794         52        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.683        0.6      0.645      0.454
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/4 [00:00<?, ?it/s]/home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       59/59         0G    0.02856    0.01645   0.006162         39        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       59/59         0G    0.02484    0.01803     0.0059         55        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       59/59         0G    0.02316    0.01858   0.005781         52        640:  /home/henrique/fiap/fase-06/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       59/59         0G    0.02453    0.01927   0.005509         59        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.733        0.6      0.689      0.477
#
# 60 epochs completed in 0.312 hours.
# Optimizer stripped from runs/train/farmtech_60epochs/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/farmtech_60epochs/weights/best.pt, 14.4MB
#
# Validating runs/train/farmtech_60epochs/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          9      0.824      0.656      0.764      0.565
#               cachorro          8          5      0.866        0.4      0.633      0.419
#                   gato          8          4      0.783      0.913      0.895      0.712
# Results saved to runs/train/farmtech_60epochs

# %% [markdown]
# ### Vamos avaliar as métricas de treinamento do modelo
#
# Ao rodar o treinamentos um arquivo de resultados será criado contendo as métricas de treinamento.
#
# Arquivo de resultados você encontra em: yolov5/runs/train/${nome_do_treinamento}

# %%
# Caminho dos resultados
results_path_30 = 'runs/train/farmtech_30epochs'

# Ler arquivo de resultados CSV
results_csv_30 = os.path.join(results_path_30, 'results.csv')
df_results_30 = pd.read_csv(results_csv_30)
df_results_30.columns = df_results_30.columns.str.strip()  # Remover espaços extras

print("📊 Métricas Finais (30 épocas):\n")
print(df_results_30.tail())


# Caminho dos resultados
results_path_60 = 'runs/train/farmtech_60epochs'

# Ler arquivo de resultados CSV
results_csv_60 = os.path.join(results_path_60, 'results.csv')
df_results_60 = pd.read_csv(results_csv_60)
df_results_60.columns = df_results_60.columns.str.strip()

print("📊 Métricas Finais (60 épocas):\n")
print(df_results_60.tail())
# Out:
# 📊 Métricas Finais (30 épocas):
#
#     epoch  train/box_loss  train/obj_loss  train/cls_loss  metrics/precision  \
# 25     25        0.036730        0.023632        0.013197            0.49298
# 26     26        0.044977        0.023438        0.012329            0.69898
# 27     27        0.050793        0.024297        0.016194            0.55597
# 28     28        0.048998        0.024483        0.013043            0.72253
# 29     29        0.042908        0.022090        0.013701            0.65964
#
#     metrics/recall  metrics/mAP_0.5  metrics/mAP_0.5:0.95  val/box_loss  \
# 25         0.67500          0.59151               0.29266      0.013483
# 26         0.66812          0.67646               0.34921      0.012615
# 27         0.66514          0.66244               0.32935      0.012731
# 28         0.55000          0.66332               0.32527      0.012446
# 29         0.55191          0.65750               0.34556      0.012068
#
#     val/obj_loss  val/cls_loss    x/lr0    x/lr1    x/lr2
# 25      0.008796      0.007831  0.00175  0.00175  0.00175
# 26      0.008786      0.007861  0.00175  0.00175  0.00175
# 27      0.008735      0.007731  0.00142  0.00142  0.00142
# 28      0.008714      0.007446  0.00109  0.00109  0.00109
# 29      0.008638      0.007252  0.00076  0.00076  0.00076
# 📊 Métricas Finais (60 épocas):
#
#     epoch  train/box_loss  train/obj_loss  train/cls_loss  metrics/precision  \
# 55     55        0.028861        0.017834        0.005467            0.81828
# 56     56        0.027862        0.019722        0.006019            0.82972
# 57     57        0.020373        0.016374        0.003732            0.76891
# 58     58        0.026853        0.016736        0.003794            0.68338
# 59     59        0.024531        0.019271        0.005509            0.73292
#
#     metrics/recall  metrics/mAP_0.5  metrics/mAP_0.5:0.95  val/box_loss  \
# 55         0.70000          0.74119               0.53918      0.009121
# 56         0.70000          0.74301               0.56191      0.009285
# 57         0.67408          0.69147               0.52216      0.008988
# 58         0.60000          0.64489               0.45409      0.008826
# 59         0.60000          0.68875               0.47692      0.008503
#
#     val/obj_loss  val/cls_loss     x/lr0     x/lr1     x/lr2
# 55      0.005550      0.007859  0.001090  0.001090  0.001090
# 56      0.005500      0.008165  0.000925  0.000925  0.000925
# 57      0.005605      0.008845  0.000760  0.000760  0.000760
# 58      0.005643      0.009107  0.000595  0.000595  0.000595
# 59      0.005689      0.009456  0.000430  0.000430  0.000430

# %% [markdown]
# ## Considerações sobre as métricas de treinamento.
#
# IMPOTANTE, explicações sobre algumas métricas
#
# **Diferença entre train/obj_loss e box_loss**:
# **train/obj_loss**: identifica a presença do objeto, enquanto o **box_loss** mede a qualidade da marcação.
#
# **metrics/mAP_0.5**:
# (IoU = 0.5), isso significa que a caixa delimitadora predita pelo modelo tem 50% de sobreposição sobre caixa delimitadora real, especifícas no arquivos labels.
# **metrics/mAP_0.5:0.95**:
# (IoU = 0.5), isso que modelo tem um precisão de 50% em marca o objeto de forma correta, com um sobreposição de 50% a 95%.
#
# ---
#
# ### Modelo de 30 Épocas
#
# Podemos obersar que:
# - **não teve overfitting** pois o **val/box_loss, val/obj_loss e val/cls_loss** vai diminuindo progressivamente ao avançar as épocas de treinamento.
# - **train/cls_loss** de  0.013197 no diz que o modelo está bom em acertar a classe (train/cls_loss <= 0.01 - modelo bom)
# - **O train/box_loss** se manteve entre 0.03 e 0.05, isso que o modelo tem um boa precisão ao marcar o objeto com a caixa delimitadora.
# - **train/obj_los** por volta de 0.02, está detectando objetos de forma confíavel, diferente da métrica acima, aqui indica que o objeto apenas foi identificado na imagem, e na métrica acima indica a assertividade na marcação do objeto.
# - **precisão (0.72)** poucos falsos positivos e **recall (0.55)** baixo, indica a ocorrência de alguns falsos negativos.
# - **mAP@0.5 (0.66)** e o **mAP@0.5:0.95 (0.34)** mostra um
#
# ### Modelo de 60 Épocas
# - **não teve overfitting**, pois o val/box_loss, val/obj_loss e val/cls_loss continuam diminuindo rogressivamente ao avançar as épocas de treinamento.
# - **train/cls_loss de 0.005467** indica que o modelo está excelente em acertar a classe, com erro de classificação muito baixo (train/cls_loss <= 0.01 - modelo bom).
# - **train/box_loss** variando entre 0.02 e 0.03 mostra que o modelo tem alta precisão na marcação das caixas delimitadoras.
# - **train/obj_loss** por volta de 0.019 demonstra que o modelo está detectando os objetos de forma estável e confiável.
# - **precisão (0.82)** mostra poucos falsos positivos, e o **recall (0.70)** mais alto em relação ao modelo de 30 épocas indica que o modelo detecta mais objetos reais e perde menos ocorrências.
# - **mAP@0.5 (0.74)** e o **mAP@0.5:0.95 (0.56)** representam uma melhoria significativa na capacidade de generalização, mostrando que o modelo se tornou mais robusto e consistente após o treinamento prolongado.

# %%
# Extrair métricas finais de ambos os treinamentos
metrics_30 = df_results_30.iloc[-1]
metrics_60 = df_results_60.iloc[-1]

# Criar DataFrame comparativo
comparison_metrics = ['metrics/precision', 'metrics/recall', 'metrics/mAP_0.5', 'metrics/mAP_0.5:0.95']
comparison_data = {
    '30 Épocas': [metrics_30[m] for m in comparison_metrics],
    '60 Épocas': [metrics_60[m] for m in comparison_metrics]
}

df_comparison = pd.DataFrame(
    comparison_data,
    index=['Precision', 'Recall', 'mAP@0.5', 'mAP@0.5:0.95']
)

# Calcular diferença percentual
df_comparison['Diferença (%)'] = ((df_comparison['60 Épocas'] - df_comparison['30 Épocas']) / df_comparison['30 Épocas'] * 100).round(2)

print("📊 Comparação de Métricas entre 30 e 60 Épocas:\n")
print(df_comparison)

# Visualização comparativa
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Gráfico de barras agrupadas
df_comparison[['30 Épocas', '60 Épocas']].plot(
    kind='bar',
    ax=axes[0],
    color=['#3498db', '#e74c3c'],
    width=0.8
)
axes[0].set_title('Comparação de Métricas de Desempenho', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Métricas', fontsize=12)
axes[0].set_ylabel('Valor', fontsize=12)
axes[0].legend(['30 Épocas', '60 Épocas'])
axes[0].grid(axis='y', alpha=0.3)
axes[0].set_xticklabels(df_comparison.index, rotation=45, ha='right')

# Gráfico de diferença percentual
colors_diff = ['#2ecc71' if x > 0 else '#e74c3c' for x in df_comparison['Diferença (%)']]
axes[1].bar(df_comparison.index, df_comparison['Diferença (%)'], color=colors_diff)
axes[1].set_title('Diferença Percentual (60 vs 30 épocas)', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Métricas', fontsize=12)
axes[1].set_ylabel('Diferença (%)', fontsize=12)
axes[1].axhline(y=0, color='black', linestyle='-', linewidth=0.8)
axes[1].grid(axis='y', alpha=0.3)
axes[1].set_xticklabels(df_comparison.index, rotation=45, ha='right')

# Adicionar valores nas barras
for i, v in enumerate(df_comparison['Diferença (%)']):
    axes[1].text(i, v + 0.5 if v > 0 else v - 0.5, f'{v:.1f}%',
                ha='center', va='bottom' if v > 0 else 'top', fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# 📊 Comparação de Métricas entre 30 e 60 Épocas:
#
#               30 Épocas  60 Épocas  Diferença (%)
# Precision       0.65964    0.73292          11.11
# Recall          0.55191    0.60000           8.71
# mAP@0.5         0.65750    0.68875           4.75
# mAP@0.5:0.95    0.34556    0.47692          38.01
# /tmp/ipykernel_79684/1075065849.py:48: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(df_comparison.index, rotation=45, ha='right')

# %% [markdown]
# ## Progressão do treinamentos
#
# Os gráficos abaixo mostra a progressão do modelo durante o treinamento, a medida que as épocas vão avançando

# %%
# Preparar dados para visualização
df_results_30_plot = df_results_30.copy()
df_results_30_plot['epochs'] = 30
df_results_30_plot['experiment'] = '30 Épocas'
df_results_60_plot = df_results_60.copy()
df_results_60_plot['epochs'] = 60
df_results_60_plot['experiment'] = '60 Épocas'

# Criar gráficos de evolução
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

metrics_to_plot = [
    ('train/box_loss', 'Loss de Box (Treino)'),
    ('train/obj_loss', 'Loss de Objectness (Treino)'),
    ('metrics/mAP_0.5', 'mAP@0.5'),
    ('metrics/mAP_0.5:0.95', 'mAP@0.5:0.95')
]

for idx, (metric, title) in enumerate(metrics_to_plot):
    row = idx // 2
    col = idx % 2

    axes[row, col].plot(df_results_30_plot.index, df_results_30_plot[metric],
                       label='30 Épocas', linewidth=2, color='#3498db')
    axes[row, col].plot(df_results_60_plot.index, df_results_60_plot[metric],
                       label='60 Épocas', linewidth=2, color='#e74c3c')

    axes[row, col].set_title(title, fontsize=12, fontweight='bold')
    axes[row, col].set_xlabel('Época', fontsize=10)
    axes[row, col].set_ylabel('Valor', fontsize=10)
    axes[row, col].legend()
    axes[row, col].grid(alpha=0.3)

plt.suptitle('Evolução das Métricas Durante o Treinamento', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Validando os modelos
#
# Aqui estamos usando o dataset de test para validar os modelos

# %%
# Validando o modelo de 30 épocas

# !python val.py \
    --weights runs/train/farmtech_30epochs/weights/best.pt \
    --data dataset.yaml \
    --img 640 \
    --task test \
    --name test_30epochs \
    --verbose
# Out:
# val: data=dataset.yaml, weights=['runs/train/farmtech_30epochs/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=test_30epochs, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-440-gf5ebc52c Python-3.12.3 torch-2.8.0+cu128 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/la
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          8      0.408      0.875      0.701      0.359
#               cachorro          8          4      0.429       0.75      0.782      0.408
#                   gato          8          4      0.386          1       0.62      0.309
# Speed: 3.6ms pre-process, 138.5ms inference, 15.0ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/test_30epochs2

# %%
# Validando o modelo de 60 épocas

# !python val.py \
    --weights runs/train/farmtech_60epochs/weights/best.pt \
    --data dataset.yaml \
    --img 640 \
    --task test \
    --name test_60epochs \
    --verbose
# Out:
# val: data=dataset.yaml, weights=['runs/train/farmtech_60epochs/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=test_60epochs, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-440-gf5ebc52c Python-3.12.3 torch-2.8.0+cu128 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/la
#                  Class     Images  Instances          P          R      mAP50
#                    all          8          8      0.889          1      0.995      0.659
#               cachorro          8          4      0.983          1      0.995      0.622
#                   gato          8          4      0.796          1      0.995      0.697
# Speed: 4.7ms pre-process, 112.4ms inference, 2.4ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/test_60epochs2

# %% [markdown]
# ## Dectando obejtos nas imagens
#
# Finalmente vamos utilizar os modelos treinados e validados para identificar os objetos nas imagens, e mostrar as marcações dos objetos.
#
# Aqui também através das imagens renderizadas vamos comparar um modelo com o outro.
#
# ---
#
# ### Como funciona a detecção.
#
# O modelo vai fazer várias marcações nas imagens, e atribuir pontuações para cada marcação, com isso podemos colocar crítérios para que somente marcações que atende a esse crítérios sejam mostradas no resultado.
#
# **--conf: 0.25** aqui mora o segredo, eu estou falando que somente caixas com uma pontuação igual ou superior a 0.25 será mostrada na imagem a qual foi feita a predição. (Essa pontuação é o nível de confiança que o modelo tem que aquele é o obejeto desejado).
#
# **--iou-thres 0.3** ao utilizar essa opção estamos falando ao modelo que somente marcações que tenha no minimo 30% de sobreposição da real, devem ser mostradas.
#
# Primeiro o modelo avalia o **--conf** descarta as marcações que não atende o crítério e depois passa pelo **--iou-thres**, ou seja, é um ajuste fino.

# %% [markdown]
# ### Usando o modelo de 30 épocas

# %%
# !python detect.py \
    --weights runs/train/farmtech_30epochs/weights/best.pt \
    --source "$test_images_path" \
    --img 640 \
    --conf 0.25 \
    --name detect_30epochs \
    --save-txt \
    --save-conf \
    --project runs/detect \
    --exist-ok
# Out:
# detect: weights=['runs/train/farmtech_30epochs/weights/best.pt'], source=../farmtech_yolo_project/dataset/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=detect_30epochs, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-440-gf5ebc52c Python-3.12.3 torch-2.8.0+cu128 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/cat.33.jpg: 512x640 1 gato, 79.6ms
# image 2/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/cat.34.jpg: 640x512 (no detections), 51.8ms
# image 3/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/cat.35.jpg: 576x640 (no detections), 61.3ms
# image 4/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/cat.36.jpg: 416x640 (no detections), 46.5ms
# image 5/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/dog.33.jpg: 512x640 1 cachorro, 58.3ms
# image 6/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/dog.34.jpg: 480x640 1 cachorro, 60.1ms
# image 7/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/dog.35.jpg: 512x640 1 cachorro, 66.7ms
# image 8/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/dog.36.jpg: 512x640 (no detections), 61.4ms
# Speed: 0.3ms pre-process, 60.7ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/detect_30epochs
# 4 labels saved to runs/detect/detect_30epochs/labels

# %% [markdown]
# ### Usando o modelo de 60 épocas

# %%
# !python detect.py \
    --weights runs/train/farmtech_60epochs/weights/best.pt \
    --source "$test_images_path" \
    --img 640 \
    --conf 0.25 \
    --name detect_60epochs \
    --save-txt \
    --save-conf \
    --project runs/detect \
    --exist-ok
# Out:
# detect: weights=['runs/train/farmtech_60epochs/weights/best.pt'], source=../farmtech_yolo_project/dataset/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=detect_60epochs, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-440-gf5ebc52c Python-3.12.3 torch-2.8.0+cu128 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/cat.33.jpg: 512x640 1 gato, 72.9ms
# image 2/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/cat.34.jpg: 640x512 1 gato, 52.0ms
# image 3/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/cat.35.jpg: 576x640 1 gato, 64.5ms
# image 4/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/cat.36.jpg: 416x640 1 gato, 59.7ms
# image 5/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/dog.33.jpg: 512x640 1 cachorro, 56.8ms
# image 6/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/dog.34.jpg: 480x640 1 cachorro, 63.6ms
# image 7/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/dog.35.jpg: 512x640 (no detections), 51.8ms
# image 8/8 /home/henrique/fiap/fase-06/farmtech_yolo_project/dataset/test/images/dog.36.jpg: 512x640 1 cachorro, 69.9ms
# Speed: 0.3ms pre-process, 61.4ms inference, 0.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/detect_60epochs
# 7 labels saved to runs/detect/detect_60epochs/labels

# %% [markdown]
# ### Imprimindo as predições
#
# Vamos imprimir as imagens preditas na detecção e avaliar os 2 modelos

# %%
import glob
import cv2
import matplotlib.pyplot as plt

pred_30 = sorted(glob.glob('runs/detect/detect_30epochs/*.jpg'))
pred_60 = sorted(glob.glob('runs/detect/detect_60epochs/*.jpg'))

def show_predictions(images, title):
    print(f"{title}: {len(images)} imagens com predição")
    
    # Criar figura para mostrar as 5 primeiras imagens
    fig, axes = plt.subplots(1, min(5, len(images)), figsize=(20, 4))
    if len(images) == 1:
        axes = [axes]
    
    for idx, img_path in enumerate(images[:5]):
        # Ler e converter imagem de BGR para RGB
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        # Mostrar imagem
        axes[idx].imshow(img)
        axes[idx].axis('off')
        axes[idx].set_title(f'Imagem {idx+1}')
    
    plt.suptitle(title, fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()

# Mostrar predições para ambos os modelos
show_predictions(pred_30, "30 épocas")
show_predictions(pred_60, "60 épocas")
# Out:
# 30 épocas: 8 imagens com predição
# 60 épocas: 8 imagens com predição
